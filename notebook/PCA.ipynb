# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv('Normal_Bearing.csv')
df2=pd.read_csv('outer_race_fault_test_2.csv')

df = pd.concat([df1,df2])
df = df.reset_index(drop=True)
df
# Out:
#        Max    Min      Mean       Std       RMS  Skewness  Kurtosis  \
# 0    0.449 -0.403 -0.001418  0.093835  0.093844  0.105575  0.196325
# 1    0.439 -0.449 -0.001834  0.095469  0.095484  0.107781  0.118071
# 2    0.481 -0.359 -0.001869  0.095178  0.095194  0.136268  0.079282
# 3    0.398 -0.369 -0.001331  0.092892  0.092900  0.123370  0.079800
# 4    0.469 -0.532 -0.002077  0.093151  0.093172  0.061563  0.183258
# ..     ...    ...       ...       ...       ...       ...       ...
# 234  0.955 -1.118 -0.001586  0.215437  0.215437 -0.080072  1.458276
# 235  0.710 -1.021 -0.001834  0.183846  0.183851 -0.146662  0.885198
# 236  0.693 -0.728 -0.001688  0.163871  0.163876  0.120602  0.264161
# 237  0.647 -0.696 -0.002102  0.158311  0.158321  0.053990  0.326583
# 238  0.593 -0.769 -0.001911  0.161196  0.161203 -0.250539  0.595927
#
#      Crest Factor  Form Factor       Fault
# 0        4.784546   -66.165911      Normal
# 1        4.597638   -52.076072      Normal
# 2        5.052829   -50.932058      Normal
# 3        4.284191   -69.776130      Normal
# 4        5.033702   -44.857827      Normal
# ..            ...          ...         ...
# 234      4.432845  -135.796235  Outer Race
# 235      3.861822  -100.230775  Outer Race
# 236      4.228812   -97.072275  Outer Race
# 237      4.086625   -75.329810  Outer Race
# 238      3.678580   -84.354015  Outer Race
#
# [239 rows x 10 columns]

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X)

from sklearn.decomposition import PCA
pca_2 = PCA(n_components=2)
X_pca = pca_2.fit_transform(X)

principalDf = pd.DataFrame(data = X_pca, columns = ['principal component 1', 'principal component 2'])

principalDf['Fault']=np.array(df['Fault'])

# %%
principalDf
# Out:
#      principal component 1  principal component 2       Fault
# 0                -3.905421              -0.875413      Normal
# 1                -3.873548              -0.779883      Normal
# 2                -4.126128              -0.155280      Normal
# 3                -4.216392              -1.768968      Normal
# 4                -3.538726               0.195341      Normal
# ..                     ...                    ...         ...
# 234               4.637371              -2.111160  Outer Race
# 235               2.408612              -2.349365  Outer Race
# 236              -0.019646              -2.477271  Outer Race
# 237              -0.342368              -1.956376  Outer Race
# 238               0.757383              -2.136381  Outer Race
#
# [239 rows x 3 columns]

# %%
principalDf['Fault'].unique()
# Out:
# array(['Normal', 'Outer Race'], dtype=object)
